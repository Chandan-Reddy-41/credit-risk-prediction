# %% [markdown]
# # Feature Engineering

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
df = pd.read_csv("Dataset_CDS/loan_approved.csv")

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)
# 0             1.0         Urban                      Y
# ...

# %%
df.value_counts()
# Out:
# Loan_ID   Gender  Married  Dependents  Education     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  Property_Area  Loan_Status (Approved)
# LP002936  Male    Yes      0           Graduate      No             3859             3300.0             142.0       180.0             1.0             Rural          Y                         1
# LP002931  Male    Yes      2           Graduate      Yes            6000             0.0                205.0       240.0             1.0             Semiurban      N                         1
# LP002928  Male    Yes      0           Graduate      No             3000             3416.0             56.0        180.0             1.0             Semiurban      Y                         1
# LP002926  Male    Yes      2           Graduate      Yes            2726             0.0                106.0       360.0             0.0             Semiurban      N                         1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  601 non-null    object
#  2   Married                 611 non-null    object
#  3   Dependents              599 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           582 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              592 non-null    float64
#  9   Loan_Amount_Term        600 non-null    float64
#  10  Credit_History          564 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                    13
# Married                    3
# Dependents                15
# Education                  0
# Self_Employed             32
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                22
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      489
# Female    112
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.histplot(x= df.ApplicantIncome, kde= True )
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %%
import seaborn as sns
sns.countplot(x= df.Gender)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.Gender.mode()[0]
# Out:
# 'Male'

# %%
df.Gender.fillna(df.Gender.mode()[0], inplace= True)

# %%
df.Gender.isnull().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
sns.countplot(x= df.Married)
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
df.Married.fillna(df.Married.mode()[0], inplace= True)

# %%
df.Married.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Married.value_counts()
# Out:
# Married
# Yes    401
# No     213
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x= df.Dependents)
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
df.Dependents.fillna(df.Dependents.mode()[0], inplace= True)

# %%
df.Dependents.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Dependents.value_counts()
# Out:
# Dependents
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(x= df.Self_Employed)
# Out:
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
df.Self_Employed.fillna(df.Self_Employed.mode()[0], inplace= True)

# %%
df.Self_Employed.isnull().sum()
# Out:
# np.int64(0)

# %%
df.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Loan_ID                    0
# Gender                     0
# Married                    0
# Dependents                 0
# Education                  0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                22
# Loan_Amount_Term          14
# Credit_History            50
# Property_Area              0
# Loan_Status (Approved)     0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
len(df.LoanAmount.unique())
# Out:
# 204

# %%
len(df.Loan_Amount_Term.unique())
# Out:
# 11

# %%
len(df.Credit_History.unique())
# Out:
# 3

# %% [markdown]
# - since loan amount term and credit history have discrete values, we will replace the null values with mode.
# - For Loan Amount we will ues the mean/median to replace the values

# %%
# Finding Outliers
sns.boxplot(x = df.ApplicantIncome)
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %% [markdown]
# - since loan amount has outliers values, we will use median to replace the null values.

# %% [raw]
# def fill_missing_values(dataframe: pd.DataFrame) -> None:
#     """
#     Fill missing values in specific columns of the dataframe with appropriate statistics.
#
#     Args:
#         dataframe (pd.DataFrame): The dataframe containing missing values to be filled.
#
#     Returns:
#         None: The dataframe is modified in-place.
#     """
#     # Fill categorical columns with mode
#     dataframe.Loan_Amount_Term.fillna(dataframe.Loan_Amount_Term.mode()[0], inplace=True)
#     dataframe.Credit_History.fillna(dataframe.Credit_History.mode()[0], inplace=True)
#
#     # Fill numerical column with median
#     dataframe.LoanAmount.fillna(dataframe.LoanAmount.median(), inplace=True)
#
# # Apply the function to the dataframe
# fill_missing_values(df)

# %%
df.Loan_Amount_Term.fillna(df.Loan_Amount_Term.mode()[0], inplace = True)
df.Credit_History.fillna(df.Credit_History.mode()[0], inplace = True)
df.LoanAmount.fillna(df.LoanAmount.median(), inplace = True)

# %%
df.isnull().sum()
# Out:
# Loan_ID                   0
# Gender                    0
# Married                   0
# Dependents                0
# Education                 0
# Self_Employed             0
# ApplicantIncome           0
# CoapplicantIncome         0
# LoanAmount                0
# Loan_Amount_Term          0
# Credit_History            0
# Property_Area             0
# Loan_Status (Approved)    0
# dtype: int64

# %%
df.head(20)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate            No
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %% [markdown]
# ## Encoding 2
# - one
# - dummy
# - ordinal
# - lable
# - manual

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Gender                  614 non-null    object
#  2   Married                 614 non-null    object
#  3   Dependents              614 non-null    object
#  4   Education               614 non-null    object
#  5   Self_Employed           614 non-null    object
#  6   ApplicantIncome         614 non-null    int64
#  7   CoapplicantIncome       614 non-null    float64
#  8   LoanAmount              614 non-null    float64
#  9   Loan_Amount_Term        614 non-null    float64
#  10  Credit_History          614 non-null    float64
#  11  Property_Area           614 non-null    object
#  12  Loan_Status (Approved)  614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64

# %%
df.Married.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+'], dtype=object)

# %%
# one hot encoding to Gender
gen_encoded = pd.get_dummies(df.Gender, dtype = int)
df = pd.concat([df, gen_encoded ], axis = 1)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Female  Male
# 0             1.0         Urban                      Y       0     1
# ...

# %%
married_encoded = pd.get_dummies(df.Married, dtype = int, drop_first = True)
df = pd.concat([df, married_encoded], axis = 1)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Female  Male  Yes
# 0             1.0         Urban                      Y       0     1    0
# ...

# %%
se_encode = pd.get_dummies(df.Self_Employed, dtype = int, drop_first = True, prefix = 'SE')
df = pd.concat([df,se_encode], axis= 1)

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
Edu_encoded = pd.get_dummies(df.Education, dtype = int, drop_first = False)
df = pd.concat([df, Edu_encoded], axis = 1)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Female  Male  Yes  \
# 0             1.0         Urban                      Y       0     1    0
# ...

# %%
df.drop(['Not Graduate'], axis = 1, inplace = True)

# %%
df.Credit_History.unique()
# Out:
# array([1., 0.])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Female  Male  Yes  \
# 0             1.0         Urban                      Y       0     1    0
# ...

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Dependents'] = le.fit_transform(df['Dependents'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No           0      Graduate            No
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001005   Male     Yes           0      Graduate           Yes
# 3  LP001006   Male     Yes           0  Not Graduate            No
# 4  LP001008   Male      No           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status (Approved)  Female  Male  Yes  \
# 0             1.0         Urban                      Y       0     1    0
# ...

# %%
df.Property_Area.unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories= [['Rural','Semiurban','Urban']])
df[['Property_Area']] = oe.fit_transform(df[['Property_Area']])

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No           0      Graduate            No
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001005   Male     Yes           0      Graduate           Yes
# 3  LP001006   Male     Yes           0  Not Graduate            No
# 4  LP001008   Male      No           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area Loan_Status (Approved)  Female  Male  Yes  \
# ...

# %%
df['Loan_Status (Approved)'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
dict1 = {
    'Y' : 1,
    'N' : 0
}
df['Loan_Status (Approved)'] = df['Loan_Status (Approved)'].map(dict1)

# %%
df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No           0      Graduate            No
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001005   Male     Yes           0      Graduate           Yes
# 3  LP001006   Male     Yes           0  Not Graduate            No
# 4  LP001008   Male      No           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Property_Area  Loan_Status (Approved)  Female  Male  Yes  \
# ...

# %%
df = df.drop(['Gender','Female','Married', 'Education', 'Self_Employed'], axis=1)

# %%
# Assuming df is your DataFrame
df.rename(columns={'Male': 'Gender'}, inplace=True)

# %%
#Assuming df is your DataFrame
df.rename(columns={'Yes': 'Married'}, inplace=True)

# %%
#Assuming df is your DataFrame
df.rename(columns={'SE_Yes': 'Self_Employed'}, inplace=True)

# %%
df.head()
# Out:
#     Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001002           0             5849                0.0       128.0
# 1  LP001003           1             4583             1508.0       128.0
# 2  LP001005           0             3000                0.0        66.0
# 3  LP001006           0             2583             2358.0       120.0
# 4  LP001008           0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Property_Area  Loan_Status (Approved)  \
# 0             360.0             1.0            2.0                       1
# 1             360.0             1.0            0.0                       0
# 2             360.0             1.0            2.0                       1
# 3             360.0             1.0            2.0                       1
# 4             360.0             1.0            2.0                       1
#
#    Gender  Married  Self_Employed  Graduate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_ID                 614 non-null    object
#  1   Dependents              614 non-null    int64
#  2   ApplicantIncome         614 non-null    int64
#  3   CoapplicantIncome       614 non-null    float64
#  4   LoanAmount              614 non-null    float64
#  5   Loan_Amount_Term        614 non-null    float64
#  6   Credit_History          614 non-null    float64
#  7   Property_Area           614 non-null    float64
#  8   Loan_Status (Approved)  614 non-null    int64
#  9   Gender                  614 non-null    int64
#  10  Married                 614 non-null    int64
#  11  Self_Employed           614 non-null    int64
#  12  Graduate                614 non-null    int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 62.5+ KB

# %%
df.head()
# Out:
#     Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001002           0             5849                0.0       128.0
# 1  LP001003           1             4583             1508.0       128.0
# 2  LP001005           0             3000                0.0        66.0
# 3  LP001006           0             2583             2358.0       120.0
# 4  LP001008           0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Property_Area  Loan_Status (Approved)  \
# 0             360.0             1.0            2.0                       1
# 1             360.0             1.0            0.0                       0
# 2             360.0             1.0            2.0                       1
# 3             360.0             1.0            2.0                       1
# 4             360.0             1.0            2.0                       1
#
#    Gender  Married  Self_Employed  Graduate
# ...

# %% [markdown]
# ## outerlaier handling

# %%
df['ApplicantIncome'].skew()
# Out:
# np.float64(6.539513113994625)

# %% [raw]
# def treat_outliers_iqr(df, column):
#     # Calculate first quartile (25th percentile)
#     Q1 = df[column].quantile(0.25)
#     # Calculate third quartile (75th percentile)
#     Q3 = df[column].quantile(0.75)
#     # Calculate interquartile range (IQR)
#     IQR = Q3 - Q1
#
#     # Define lower boundary for outliers (Q1 - 1.5*IQR)
#     lower_limit = Q1 - 1.5 * IQR
#     # Define upper boundary for outliers (Q3 + 1.5*IQR)
#     upper_limit = Q3 + 1.5 * IQR
#
#     # Option 1 (Capping): Replace outliers with limits
#     # Any value below lower_limit will be set to lower_limit
#     # Any value above upper_limit will be set to upper_limit
#     df[column] = df[column].clip(lower_limit, upper_limit)
#
#     # Option 2 (Removing): Uncomment line below to remove rows
#     # This alternative approach would remove rows containing outliers instead of capping them
#     # df = df[(df[column] >= lower_limit) & (df[column] <= upper_limit)]
#
#     return df

# %% [raw]
# # Apply IQR method to handle outliers in the 'Fare' column
# df = treat_outliers_iqr(df, 'ApplicantIncome')

# %%
len(df[df['ApplicantIncome'] > 10171.25])
# Out:
# 50

# %%
len(df[df['ApplicantIncome'] < 1498.75])
# Out:
# 11

# %%
len(df[(df['ApplicantIncome'] > 10171.25) | (df['ApplicantIncome'] < 1498.75)])
# Out:
# 61

# %%
# Option 2 (Removing): Uncomment line below to remove rows
# This alternative approach would remove rows containing outliers instead of capping them
# Option 2 (Removing outliers)
df_ot = df[(df['ApplicantIncome'] >= 10171.25) | (df['ApplicantIncome'] <= 1498.75)]

# %%
len(df[df['CoapplicantIncome'] > 10171.25])
# Out:
# 6

# %%
len(df[df['CoapplicantIncome'] < 1498.75])
# Out:
# 338

# %%
len(df[(df['CoapplicantIncome'] > 10171.25) | (df['CoapplicantIncome'] < 1498.75)])
# Out:
# 344

# %%
df_ot
# Out:
#       Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 9    LP001020           1            12841            10968.0       349.0
# 14   LP001030           2             1299             1086.0        17.0
# 28   LP001086           0             1442                0.0        35.0
# 34   LP001100           3            12500             3000.0       320.0
# 54   LP001186           1            11500                0.0       286.0
# ..        ...         ...              ...                ...         ...
# 561  LP002813           1            19484                0.0       600.0
# 572  LP002855           2            16666                0.0       275.0
# 594  LP002938           0            16120                0.0       260.0
# 600  LP002949           3              416            41667.0       350.0
# 604  LP002959           1            12000                0.0       496.0
#
#      Loan_Amount_Term  Credit_History  Property_Area  Loan_Status (Approved)  \
# ...

# %%
# Finding Outliers
sns.boxplot(x = df.ApplicantIncome)
# Out:
# <Axes: xlabel='ApplicantIncome'>

# %%
# Finding Outliers
sns.boxplot(x = df.CoapplicantIncome)
# Out:
# <Axes: xlabel='CoapplicantIncome'>

# %%
# Finding Outliers
sns.boxplot(x = df.LoanAmount)
# Out:
# <Axes: xlabel='LoanAmount'>

# %%
# iqr for applicant income
import numpy as np
Q1_AI = np.percentile(df.ApplicantIncome, 25)
Q3_AI = np.percentile(df.ApplicantIncome, 75)

# %%
IQR_AI = Q3_AI - Q1_AI

# %%
UB_AI = Q3_AI + 1.5 * IQR_AI
LB_AI = Q1_AI - 1.5 * IQR_AI

# %%
df = df.loc[(df.ApplicantIncome >LB_AI) & (df.ApplicantIncome < UB_AI)]

# %%
# no of outliers
614-564
# Out:
# 50

# %%
# percentage of outilers
50/614 * 100
# Out:
# 8.143322475570033

# %%
from scipy.stats.mstats import winsorize
df['CoapplicantIncome'] = winsorize(df.CoapplicantIncome, limits = 0.1)

# %%
sns.boxplot(x= df.CoapplicantIncome)
# Out:
# <Axes: xlabel='CoapplicantIncome'>

# %%
df.head()
# Out:
#     Loan_ID  Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0  LP001002           0             5849                0.0       128.0
# 1  LP001003           1             4583             1508.0       128.0
# 2  LP001005           0             3000                0.0        66.0
# 3  LP001006           0             2583             2358.0       120.0
# 4  LP001008           0             6000                0.0       141.0
#
#    Loan_Amount_Term  Credit_History  Property_Area  Loan_Status (Approved)  \
# 0             360.0             1.0            2.0                       1
# 1             360.0             1.0            0.0                       0
# 2             360.0             1.0            2.0                       1
# 3             360.0             1.0            2.0                       1
# 4             360.0             1.0            2.0                       1
#
#    Gender  Married  Self_Employed  Graduate
# ...

# %%
df['ApplicantIncome'].max()
# Out:
# 10139

# %%
df['ApplicantIncome'].min()
# Out:
# 150

# %%
x = df.drop(columns= ['Loan_Status (Approved)', 'Loan_ID'])
y = df['Loan_Status (Approved)']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=13)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
print(x_train)
# Out:
# [[0.         0.38375265 0.45653319 ... 1.         0.         1.        ]
#  [0.         0.90259675 0.         ... 1.         0.         1.        ]
#  [0.         0.22966556 0.13303477 ... 1.         0.         1.        ]
#  ...
#  [1.         0.30483985 1.         ... 1.         0.         1.        ]
#  [0.33333333 0.30059614 0.68045311 ... 1.         0.         1.        ]
#  [0.         0.23744569 0.         ... 0.         0.         1.        ]]

# %%
print(x_test)
# Out:
# [[0.         0.17843791 1.         ... 0.         0.         1.        ]
#  [0.66666667 0.92684652 1.         ... 1.         1.         1.        ]
#  [0.         0.82681621 0.98788198 ... 0.         0.         1.        ]
#  ...
#  [0.         0.20925533 0.         ... 1.         0.         1.        ]
#  [0.         0.13054461 0.         ... 0.         0.         0.        ]
#  [0.66666667 0.17429524 0.49394099 ... 1.         1.         0.        ]]

# %%
print(y_train)
# Out:
# 452    0
# 350    1
# 354    1
# 431    0
# 37     1
#       ..
# 168    0
# 576    0
# 78     0
# 195    0
# 366    0
# Name: Loan_Status (Approved), Length: 451, dtype: int64

# %%
print(y_test)
# Out:
# 181    0
# 372    1
# 196    1
# 449    0
# 340    0
#       ..
# 217    1
# 362    1
# 220    0
# 28     0
# 71     1
# Name: Loan_Status (Approved), Length: 113, dtype: int64

# %%
df = pd.read_csv('Dataset_CDS\covid_toy.csv')
